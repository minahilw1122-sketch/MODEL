# %%
import pandas as pd

# %%
df = pd.read_csv("cleaned_dataset.csv")

# %%
df.head()

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np

# Features and target
X = df.drop(columns="Total Spent", axis=1)
y = df["Total Spent"]  # fixed: removed trailing space

# Split the data
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.1, random_state=42
)

# Initialize and train the model
model = XGBRegressor(n_estimators=100, random_state=42, learning_rate=0.1)  # fixed: n_estimators
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate
print("R2_SCORE:", r2_score(y_test, y_pred))
print("MEAN_SQUARED_ERROR:", mean_squared_error(y_test, y_pred))
# Out:
# R2_SCORE: 0.9690061233339007
# MEAN_SQUARED_ERROR: 285.7950835208479

# %%
df.head()
# Out:
#    Category  Item  Price Per Unit  Quantity  Total Spent  Discount Applied  \
# 0         7     7            18.5      10.0        185.0                 1
# 1         6    62            29.0       9.0        261.0                 1
# 2         1    17            21.5       2.0         43.0                 0
# 3         0    48            27.5       9.0        247.5                 1
# 4         4   172            12.5       7.0         87.5                 0
#
#    Payment Method_Cash  Payment Method_Credit Card  \
# 0                    0                           0
# 1                    0                           0
# 2                    0                           1
# 3                    0                           1
# 4                    0                           0
#
#    Payment Method_Digital Wallet  Location_In-store  Location_Online
# 0                              1                  0                1
# ...

# %%
import numpy as np
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE:", rmse)
# Out:
# RMSE: 16.905474956973197

# %%
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np

# Predictions
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Metrics
train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)

train_rmse = np.sqrt(mean_squared_error(y_train, y_train_pred))
test_rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))

print(f"TRAIN R2: {train_r2:.3f}, TEST R2: {test_r2:.3f}")
print(f"TRAIN RMSE: {train_rmse:.3f}, TEST RMSE: {test_rmse:.3f}")
# Out:
# TRAIN R2: 0.979, TEST R2: 0.969
# TRAIN RMSE: 13.227, TEST RMSE: 16.905

# %%
import pickle
with open("xgb_model.pkl", "wb") as f:
    pickle.dump(model, f)
